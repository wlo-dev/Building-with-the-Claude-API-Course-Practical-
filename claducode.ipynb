# %%
# install dependencies

# %pip install anthropic python-dotenv

# %%
# Load environment variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API Client

from anthropic import Anthropic

client = Anthropic()
model= "claude-sonnet-4-0"

# %%
def add_user_message(messages, text):
    user_message ={"role": "user", "content": text}
    messages.append(user_message)

# %%
def add_assistant_message(messages, text):
    assistant_message ={"role": "assistant", "content": text}
    messages.append(assistant_message)
    
    return messages.content[0].text

# %%
# Make a request to the API
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {"role": "user", 
         "content": "What is quantum computing? Answer in two sentences."}
    ]
)

# %%
message.content[0].text

# %%
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {"role": "user", 
         "content": "Write another sentence about quantum computing."
         }
    ],
    
)
message.content[0].text

# %%
# Make a starting list of messages

# Add in the initial user questions of "Define what is quantum computing in two sentences."

#Pass the list of messages into 'chat' to get an answer from the model.

# Take the model's answer and add it to the list of messages.

#  Ad it into the user's follow-uo question

# Call chat again with thw list of messages to get a final answer from the model.
